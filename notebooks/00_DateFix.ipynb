# %%
import pandas as pd

# File paths
input_file = "RAG_news.csv"
output_file = "RAG_news_sorted.csv"

# Read the CSV file
df = pd.read_csv(input_file)

# Ensure newsDatetime is treated as datetime
df['newsDatetime'] = pd.to_datetime(df['newsDatetime'])

# Sort by newsDatetime
df = df.sort_values(by='newsDatetime').reset_index(drop=True)

# Save to new CSV
df.to_csv(output_file, index=False)

print(f"Saved sorted file to {output_file}")
# Out:
# Saved sorted file to RAG_news_sorted.csv

# %%
import pandas as pd

# File paths
input_file = "RAG_news.csv"
output_file = "RAG_news_2025.csv"

# Read the CSV file
df = pd.read_csv(input_file)

# Ensure newsDatetime is treated as datetime
df['newsDatetime'] = pd.to_datetime(df['newsDatetime'])

# Filter for 2025
df_2025 = df[df['newsDatetime'].dt.year == 2025]

# Display (print) the 2025 rows
print(df_2025)

# Save to new CSV
df_2025.to_csv(output_file, index=False)
print(f"Saved 2025 news to {output_file}")
# Out:
#            id                                              title  \
# 22166  174627  Ripple’s XRP takes second place in trade in So...
# 22167  174628  Andrew Tate Launches BRUV Party, Eyes Bitcoin ...
# 22168  174629  Cardano's Price Might Reclaim $1.20 in Days, H...
# 22169  174630  Cardano’s 2025 Strategy: Wallet Innovation and...
# 22170  174631  MicroStrategy Plans $2B Stock Offering to Boos...
# ...       ...                                                ...
# 24253  225824  Trump Coin Whales Dump $6.4M Ahead Of VIP Meme...
# 24254  225825  Over 760K lost money on Donald Trump's memecoi...
# 24255  225826  Trump to host memecoin gala dinner amid backla...
# 24256  226047  Vitalik Buterin praises real-time ZK proving m...
# 24257  226185  Cardano to Directly Feature Blockchain and Ass...
#
#                                              description        newsDatetime  \
# 22166  A recent survey by South Korea’s News1 has rev... 2025-01-07 15:13:49
# 22167  Tate has launched the BRUV Party, short for “B... 2025-01-07 09:03:30
# 22168  Cardano on positive momentum streak in correla... 2025-01-06 15:07:00
# 22169  Charles Hoskinson, the founder of Cardano, rec... 2025-01-05 17:00:16
# 22170  MicroStrategy plans to raise $2 billion from a... 2025-01-04 18:01:49
# ...                                                  ...                 ...
# 24253  Two huge memecoin whales trigger multi-million... 2025-05-13 20:40:00
# 24254  Over 764,000 wallets are in the red as Trump’s... 2025-05-06 22:30:00
# 24255  US President Donald Trump will host a gala din... 2025-05-05 13:33:35
# 24256  Ethereum co-founder Vitalik Buterin acknowledg... 2025-05-21 20:15:10
# 24257  Brave Wallet, the crypto wallet integrated int... 2025-05-13 09:02:54
#
#                                                      url  positiveVotes  \
# 22166  https://cryptopanic.com/news/20517107/Ripples-...              1
# 22167  https://cryptopanic.com/news/20515199/Andrew-T...              6
# 22168  https://cryptopanic.com/news/20511717/Cardanos...              4
# 22169  https://cryptopanic.com/news/20508114/Cardanos...             10
# 22170  https://cryptopanic.com/news/20506082/MicroStr...              4
# ...                                                  ...            ...
# 24253  https://cryptopanic.com/news/21773506/Trump-Co...              0
# 24254  https://cryptopanic.com/news/21606209/Over-760...              0
# 24255  https://cryptopanic.com/news/21568390/Trump-to...              3
# 24256  https://cryptopanic.com/news/21987380/Vitalik-...              1
# 24257  https://cryptopanic.com/news/21758336/Cardano-...              1
#
#        negativeVotes                                          sourceUrl  \
# 22166              2  https://www.cryptopolitan.com/ripples-xrp-take...
# 22167              0  https://www.altcoinbuzz.io/cryptocurrency-news...
# 22168              3  https://u.today/cardanos-price-might-reclaim-1...
# 22169             10  https://cryptodnes.bg/en/cardanos-2025-strateg...
# 22170              0  https://www.cryptopolitan.com/microstrategy-pl...
# ...              ...                                                ...
# 24253              5  https://dailycoin.com/trump-coin-whales-dump-6...
# 24254              4  https://www.thestreet.com/crypto/markets/over-...
# 24255              1  https://cointelegraph.com/news/trump-s-stablec...
# 24256              1  https://cryptoslate.com/vitalik-buterin-praise...
# 24257              1  https://www.coindesk.com/markets/2025/05/13/ca...
#
#            currencies
# 22166     BTC,ETH,XRP
# 22167             BTC
# 22168         BTC,ADA
# 22169         BTC,ADA
# 22170             BTC
# ...               ...
# 24253           TRUMP
# 24254           TRUMP
# 24255           TRUMP
# 24256          ETH,ZK
# 24257  ETH,ADA,SOL,IO
#
# [1192 rows x 9 columns]
# Saved 2025 news to RAG_news_2025.csv

# %%
import pandas as pd

# File paths
input_file = "RAG_news.csv"
output_file = "RAG_news_2024_2025_sorted.csv"

# Read the CSV file
df = pd.read_csv(input_file)

# Ensure newsDatetime is datetime
df['newsDatetime'] = pd.to_datetime(df['newsDatetime'])

# Filter for 2024 and 2025
df_filtered = df[df['newsDatetime'].dt.year.isin([2024, 2025])]

# Sort from beginning of 2024 to end of 2025
df_sorted = df_filtered.sort_values(by='newsDatetime', ascending=True).reset_index(drop=True)

# Save to new CSV
df_sorted.to_csv(output_file, index=False)
print(f"Saved sorted 2024 & 2025 news to {output_file}")
# Out:
# Saved sorted 2024 & 2025 news to RAG_news_2024_2025_sorted.csv

# %%
import pandas as pd

# File paths
input_file = "RAG_news_2024_2025_sorted.csv"  # <- only 2024 and 2025 news
output_file = "RAG_news_2024_2025_updated_dates.csv"

# Read the CSV
df = pd.read_csv(input_file)

# Ensure newsDatetime is datetime
df['newsDatetime'] = pd.to_datetime(df['newsDatetime'])

# Define date range to change from 2024 to 2025
start = pd.to_datetime('2024-05-24')
end   = pd.to_datetime('2024-07-31')

# Mask: dates in 2024 and between start & end
mask = (df['newsDatetime'] >= start) & (df['newsDatetime'] <= end) & (df['newsDatetime'].dt.year == 2024)

# Update the year to 2025 for these rows
df.loc[mask, 'newsDatetime'] = df.loc[mask, 'newsDatetime'].apply(lambda x: x.replace(year=2025))

# Sort by newsDatetime
df = df.sort_values(by='newsDatetime', ascending=True).reset_index(drop=True)

# Save to new CSV
df.to_csv(output_file, index=False)
print(f"Updated dates and saved to {output_file}")
# Out:
# Updated dates and saved to RAG_news_2024_2025_updated_dates.csv

# %%
import pandas as pd

# File paths
input_file = "RAG_new_2024-2025.csv"
output_file = "RAG_new_2024-2025_switched.csv"

# Read the CSV
df = pd.read_csv(input_file)

# Ensure newsDatetime is datetime
df['newsDatetime'] = pd.to_datetime(df['newsDatetime'])

# Define date range
start = pd.to_datetime('2025-05-24')
end   = pd.to_datetime('2025-07-31')

# Mask: rows in the date range
mask = (df['newsDatetime'] >= start) & (df['newsDatetime'] <= end)

# Columns to check/replace
cols = ['title', 'description', 'url', 'sourceUrl']

# For each column, replace '2024' with '2025' in the masked rows
for col in cols:
    df.loc[mask, col] = df.loc[mask, col].astype(str).str.replace('2024', '2025', regex=False)

# Save to new CSV
df.to_csv(output_file, index=False)
print(f"Switched '2024' to '2025' in date range and saved to {output_file}")
# Out:
# Switched '2024' to '2025' in date range and saved to RAG_new_2024-2025_switched.csv

# %%
import pandas as pd

# Load the processed file
df = pd.read_csv("RAG_new_2024-2025_switched.csv")

# Display only the specified columns
df[['positiveVotes', 'negativeVotes', 'sourceUrl', 'currencies']]
# Out:
#       positiveVotes  negativeVotes  \
# 0                 4              7
# 1                 1              1
# 2                 0              4
# 3                 2              0
# 4                 3              0
# ...             ...            ...
# 4573              2              3
# 4574              6              5
# 4575              3              1
# 4576              1              4
# 4577              3              0
#
#                                               sourceUrl  \
# 0     https://u.today/cardano-ada-skyrockets-in-this...
# 1     https://finbold.com/4-altcoins-to-buy-under-1-...
# 2     https://www.cryptopolitan.com/five-bitcoin-min...
# 3     https://www.newsbtc.com/news/ethereum/ethereum...
# 4     https://www.benzinga.com/markets/cryptocurrenc...
# ...                                                 ...
# 4573  https://u.today/cardano-inching-closer-to-chan...
# 4574  https://u.today/cardano-ada-prediction-for-jul...
# 4575  https://finbold.com/rich-dad-r-kiyosaki-reveal...
# 4576  https://ambcrypto.com/will-solana-become-a-tru...
# 4577  https://dailycoin.com/polygon-matic-gets-movev...
#
#                   currencies
# 0                        ADA
# 1     BTC,ADA,XRP,MATIC,ALGO
# 2                        BTC
# 3                BTC,ETH,GRT
# 4               BTC,ETH,DOGE
# ...                      ...
# 4573                     ADA
# 4574                     ADA
# 4575             BTC,ETH,SOL
# 4576                 ETH,SOL
# 4577               ETH,MATIC
#
# [4578 rows x 4 columns]

# %%
import pandas as pd

# Load your file
df = pd.read_csv("RAG_new_2024-2025.csv")

# Split the 'currencies' column by comma, then explode it into separate rows
df['currencies'] = df['currencies'].astype(str).str.split(',')

# Explode so each currency gets its own row
df_exploded = df.explode('currencies').reset_index(drop=True)

# Clean up whitespace around currency names
df_exploded['currencies'] = df_exploded['currencies'].str.strip()

# Save the exploded DataFrame
df_exploded.to_csv("RAG_new_2024-2025_exploded.csv", index=False)

print("Done! Each row now has only one currency. Saved as RAG_new_2024-2025_exploded.csv")
# Out:
# Done! Each row now has only one currency. Saved as RAG_new_2024-2025_exploded.csv

# %%
import pandas as pd

df = pd.read_csv("RAG_new_2024-2025.csv")
df  # Just type the variable name in a cell to see a nice table!
# Out:
#           id                                              title  \
# 0     148257  Cardano (ADA) Skyrockets in This Bullish Metri...
# 1     152291       4 altcoins to buy under $1 for start of 2024
# 2     152291       4 altcoins to buy under $1 for start of 2024
# 3     152291       4 altcoins to buy under $1 for start of 2024
# 4     152291       4 altcoins to buy under $1 for start of 2024
# ...      ...                                                ...
# 7666  164101  ‘Rich Dad’ R. Kiyosaki reveals the only 3 cryp...
# 7667  164438  Will Solana become a true ‘Ethereum killer’ in...
# 7668  164438  Will Solana become a true ‘Ethereum killer’ in...
# 7669  164437  Polygon (MATIC) Gets MoveVM Boost in Goal to B...
# 7670  164437  Polygon (MATIC) Gets MoveVM Boost in Goal to B...
#
#                                             description         newsDatetime  \
# 0           Majority of growth occurred in mid-December  2024-01-01 12:14:00
# 1     After altcoins took a breather in the final we...  2024-01-01 14:00:00
# 2     After altcoins took a breather in the final we...  2024-01-01 14:00:00
# 3     After altcoins took a breather in the final we...  2024-01-01 14:00:00
# 4     After altcoins took a breather in the final we...  2024-01-01 14:00:00
# ...                                                 ...                  ...
# 7666  Though often viewed as controversial, Robert K...  2025-07-30 15:24:51
# 7667  Solana's total value locked has surged by 25%,...  2025-07-30 22:00:25
# 7668  Solana's total value locked has surged by 25%,...  2025-07-30 22:00:25
# 7669  MoveVM Chains are coming to the AggLayer in a ...  2025-07-30 22:35:00
# 7670  MoveVM Chains are coming to the AggLayer in a ...  2025-07-30 22:35:00
#
#                                                     url  positiveVotes  \
# 0     https://cryptopanic.com/news/19143576/Cardano-...              4
# 1     https://cryptopanic.com/news/19143677/4-altcoi...              1
# 2     https://cryptopanic.com/news/19143677/4-altcoi...              1
# 3     https://cryptopanic.com/news/19143677/4-altcoi...              1
# 4     https://cryptopanic.com/news/19143677/4-altcoi...              1
# ...                                                 ...            ...
# 7666  https://cryptopanic.com/news/19741440/Rich-Dad...              3
# 7667  https://cryptopanic.com/news/19742703/Will-Sol...              1
# 7668  https://cryptopanic.com/news/19742703/Will-Sol...              1
# 7669  https://cryptopanic.com/news/19742767/Polygon-...              3
# 7670  https://cryptopanic.com/news/19742767/Polygon-...              3
#
#       negativeVotes                                          sourceUrl  \
# 0                 7  https://u.today/cardano-ada-skyrockets-in-this...
# 1                 1  https://finbold.com/4-altcoins-to-buy-under-1-...
# 2                 1  https://finbold.com/4-altcoins-to-buy-under-1-...
# 3                 1  https://finbold.com/4-altcoins-to-buy-under-1-...
# 4                 1  https://finbold.com/4-altcoins-to-buy-under-1-...
# ...             ...                                                ...
# 7666              1  https://finbold.com/rich-dad-r-kiyosaki-reveal...
# 7667              4  https://ambcrypto.com/will-solana-become-a-tru...
# 7668              4  https://ambcrypto.com/will-solana-become-a-tru...
# 7669              0  https://dailycoin.com/polygon-matic-gets-movev...
# 7670              0  https://dailycoin.com/polygon-matic-gets-movev...
#
#      currencies
# 0           ADA
# 1           BTC
# 2           ADA
# 3           XRP
# 4         MATIC
# ...         ...
# 7666        SOL
# 7667        ETH
# 7668        SOL
# 7669        ETH
# 7670      MATIC
#
# [7671 rows x 9 columns]
